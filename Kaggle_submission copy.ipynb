# %% [markdown]
# ## Kaggle – DataTops®
# Luismi ha decidido cambiar de aires y, por eso, ha comprado una tienda de portátiles. Sin embargo, su única especialidad es Data Science, por lo que ha decidido crear un modelo de ML para establecer los mejores precios.
#
# ¿Podrías ayudar a Luismi a mejorar ese modelo?

# %% [markdown]
# ## Métrica:
# Error de raíz cuadrada media (RMSE) es la desviación estándar de los valores residuales (errores de predicción). Los valores residuales son una medida de la distancia de los puntos de datos de la línea de regresión; RMSE es una medida de cuál es el nivel de dispersión de estos valores residuales. En otras palabras, le indica el nivel de concentración de los datos en la línea de mejor ajuste.
#
#
# $$ RMSE = \sqrt{\frac{1}{n}\Sigma_{i=1}^{n}{\Big(\frac{d_i -f_i}{\sigma_i}\Big)^2}}$$

# %% [markdown]
# ## Librerías

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import root_mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import urllib.request
import bootcampviztools as bt
import toolbox_ML as tml

# %% [markdown]
# ## Datos

# %%
# Para que funcione necesitas bajarte los archivos de datos de Kaggle 
df = pd.read_csv("./data/train.csv", index_col=0)
df.index.name = None

# %% [markdown]
# ## Exploración de los datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 755 to 229
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           912 non-null    object
#  1   Product           912 non-null    object
#  2   TypeName          912 non-null    object
#  3   Inches            912 non-null    float64
#  4   ScreenResolution  912 non-null    object
#  5   Cpu               912 non-null    object
#  6   Ram               912 non-null    object
#  7   Memory            912 non-null    object
#  8   Gpu               912 non-null    object
#  9   OpSys             912 non-null    object
#  10  Weight            912 non-null    object
#  11  Price_in_euros    912 non-null    float64
# dtypes: float64(2), object(10)
# memory usage: 92.6+ KB

# %%
df.head()
# Out:
#     Company        Product   TypeName  Inches   ScreenResolution  \
# 755      HP         250 G6   Notebook    15.6  Full HD 1920x1080
# 618    Dell  Inspiron 7559     Gaming    15.6  Full HD 1920x1080
# 909      HP    ProBook 450   Notebook    15.6  Full HD 1920x1080
# 2     Apple    Macbook Air  Ultrabook    13.3           1440x900
# 286    Dell  Inspiron 3567   Notebook    15.6  Full HD 1920x1080
#
#                              Cpu   Ram               Memory  \
# 755     Intel Core i3 6006U 2GHz   8GB            256GB SSD
# 618  Intel Core i7 6700HQ 2.6GHz  16GB              1TB HDD
# 909   Intel Core i7 7500U 2.7GHz   8GB              1TB HDD
# 2           Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 286   Intel Core i3 6006U 2.0GHz   4GB              1TB HDD
#
#                                 Gpu       OpSys  Weight  Price_in_euros
# 755           Intel HD Graphics 520  Windows 10  1.86kg          539.00
# 618  Nvidia GeForce GTX 960<U+039C>  Windows 10  2.59kg          879.01
# 909            Nvidia GeForce 930MX  Windows 10  2.04kg          900.00
# 2            Intel HD Graphics 6000       macOS  1.34kg          898.94
# 286              AMD Radeon R5 M430       Linux  2.25kg          428.00

# %%
df.describe()
# Out:
#            Inches  Price_in_euros
# count  912.000000      912.000000
# mean    14.981579     1111.724090
# std      1.436719      687.959172
# min     10.100000      174.000000
# 25%     14.000000      589.000000
# 50%     15.600000      978.000000
# 75%     15.600000     1483.942500
# max     18.400000     6099.000000

# %% [markdown]
# ## Procesado de datos

# %% [markdown]
# Nuestro target es la columna `Price_in_euros`

# %%
#df[df.duplicated()].sort_values("Product")

# %%
#df = df.drop_duplicates()

# %%
#df[df.duplicated()].sort_values("Product")

# %%
df['apple'] = df['Company'].str.contains(r'Apple', case=False, na=False).astype(int)

# %%
df.drop(columns=["Company", "Product"], inplace=True)

# %%
df['i3'] = df['Cpu'].str.contains(r'i3', case=False, na=False).astype(int)
df['i5'] = df['Cpu'].str.contains(r'i5', case=False, na=False).astype(int)
df['i7'] = df['Cpu'].str.contains(r'i7', case=False, na=False).astype(int)

# %%
df["inches"] = df.Inches.astype(float)
df['ram_gb'] = df['Ram'].str.replace('GB', '').astype(int)
df["weight_kg"] = df['Weight'].str.replace('kg', '').astype(float)

# %%
df.head()
# Out:
#       TypeName  Inches   ScreenResolution                          Cpu   Ram  \
# 755   Notebook    15.6  Full HD 1920x1080     Intel Core i3 6006U 2GHz   8GB
# 618     Gaming    15.6  Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  16GB
# 909   Notebook    15.6  Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB
# 2    Ultrabook    13.3           1440x900         Intel Core i5 1.8GHz   8GB
# 286   Notebook    15.6  Full HD 1920x1080   Intel Core i3 6006U 2.0GHz   4GB
#
#                   Memory                             Gpu       OpSys  Weight  \
# 755            256GB SSD           Intel HD Graphics 520  Windows 10  1.86kg
# 618              1TB HDD  Nvidia GeForce GTX 960<U+039C>  Windows 10  2.59kg
# 909              1TB HDD            Nvidia GeForce 930MX  Windows 10  2.04kg
# 2    128GB Flash Storage          Intel HD Graphics 6000       macOS  1.34kg
# 286              1TB HDD              AMD Radeon R5 M430       Linux  2.25kg
#
#      Price_in_euros  apple  i3  i5  i7  inches  ram_gb  weight_kg
# 755          539.00      0   1   0   0    15.6       8       1.86
# 618          879.01      0   0   0   1    15.6      16       2.59
# 909          900.00      0   0   0   1    15.6       8       2.04
# 2            898.94      1   0   1   0    13.3       8       1.34
# 286          428.00      0   1   0   0    15.6       4       2.25

# %%
df["Touchscreen"] = df["ScreenResolution"].str.contains("Touchscreen").astype(int)

# %%
df["IPS"] = df["ScreenResolution"].str.contains("IPS").astype(int)

# %%
df["4K"] = df["ScreenResolution"].str.contains("4K").astype(int)

# %%
find_GB_TB = df["Memory"].str.findall(r"(\d+)(GB|TB)")

def convert_to_gb(list_of_tuples):
    total_gb = 0
    if list_of_tuples: 
        for (num, unit) in list_of_tuples:
            num = float(num)
            if unit == "TB":
                total_gb += num * 1024
            else: 
                total_gb += num
    return total_gb

df["total_memory_gb"] = find_GB_TB.apply(convert_to_gb)

# %%
df = pd.get_dummies(df, columns=["TypeName"], prefix="type")

# %%
df["type_2in1_convertible"] = df["type_2 in 1 Convertible"]
df.drop("type_2 in 1 Convertible", axis=1, inplace=True)

# %%
df[["width", "height"]] = df["ScreenResolution"].str.extract(r"(\d+)x(\d+)").astype(int)
df["total_pixels"] = df["width"] * df["height"]
df.head(3)
# Out:
#      Inches   ScreenResolution                          Cpu   Ram     Memory  \
# 755    15.6  Full HD 1920x1080     Intel Core i3 6006U 2GHz   8GB  256GB SSD
# 618    15.6  Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  16GB    1TB HDD
# 909    15.6  Full HD 1920x1080   Intel Core i7 7500U 2.7GHz   8GB    1TB HDD
#
#                                 Gpu       OpSys  Weight  Price_in_euros  \
# 755           Intel HD Graphics 520  Windows 10  1.86kg          539.00
# 618  Nvidia GeForce GTX 960<U+039C>  Windows 10  2.59kg          879.01
# 909            Nvidia GeForce 930MX  Windows 10  2.04kg          900.00
#
#      apple  ...  total_memory_gb  type_Gaming  type_Netbook  type_Notebook  \
# 755      0  ...            256.0        False         False           True
# 618      0  ...           1024.0         True         False          False
# 909      0  ...           1024.0        False         False           True
#
#      type_Ultrabook  type_Workstation  type_2in1_convertible  width  height  \
# 755           False             False                  False   1920    1080
# 618           False             False                  False   1920    1080
# 909           False             False                  False   1920    1080
#
#      total_pixels
# 755       2073600
# 618       2073600
# 909       2073600
#
# [3 rows x 29 columns]

# %%
df['GPU_Nvidia'] = df['Gpu'].str.contains('Nvidia').astype(int)
df['GPU_Intel'] = df['Gpu'].str.contains('Intel').astype(int)
df['GPU_AMD'] = df['Gpu'].str.contains('AMD').astype(int)

print(df['GPU_AMD'].sum()+df['GPU_Intel'].sum()+df['GPU_Nvidia'].sum())
# Out:
# 912

# %%
df["Frecuencia_GHz"] = df["Cpu"].str.extract(r"(\d+(?:\.\d+)?)GHz")
df.Frecuencia_GHz = df["Frecuencia_GHz"].astype(float)

# %%
df.drop(columns=["Cpu","Memory", "Ram", "Inches", "Weight", "ScreenResolution"], inplace=True)
df.head(3)
# Out:
#                                 Gpu       OpSys  Price_in_euros  apple  i3  \
# 755           Intel HD Graphics 520  Windows 10          539.00      0   1
# 618  Nvidia GeForce GTX 960<U+039C>  Windows 10          879.01      0   0
# 909            Nvidia GeForce 930MX  Windows 10          900.00      0   0
#
#      i5  i7  inches  ram_gb  weight_kg  ...  type_Ultrabook  type_Workstation  \
# 755   0   0    15.6       8       1.86  ...           False             False
# 618   0   1    15.6      16       2.59  ...           False             False
# 909   0   1    15.6       8       2.04  ...           False             False
#
#      type_2in1_convertible  width  height  total_pixels  GPU_Nvidia  \
# 755                  False   1920    1080       2073600           0
# 618                  False   1920    1080       2073600           1
# 909                  False   1920    1080       2073600           1
#
#      GPU_Intel  GPU_AMD  Frecuencia_GHz
# 755          1        0             2.0
# 618          0        0             2.6
# 909          0        0             2.7
#
# [3 rows x 27 columns]

# %%
# Outliers de target
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Price_in_euros"])
plt.title("Boxplot de Price_in_euros")
plt.show()

# %%
# Eliminar Outliers del target
df = df[df["Price_in_euros"] < 4200]
df.Price_in_euros.isnull().sum()
# Out:
# 0

# %%
#df[df.Price_in_euros > 4000]

# %%
# Outliers de target
plt.figure(figsize=(10,5))
sns.boxplot(x=df["Price_in_euros"])
plt.title("Boxplot de Price_in_euros")
plt.show()

# %%
#df.Price_in_euros.fillna(df.Price_in_euros.mean(), inplace=True)

# %%
df.Price_in_euros = df.Price_in_euros.astype(float).round(2)
df.Price_in_euros.sample(1)
# Out:
# 1200    895.01
# Name: Price_in_euros, dtype: float64

# %%
df.drop(columns=["width", "height"], inplace=True)

# %%
df['GPU_GeForceGTX'] = df['Gpu'].str.contains('GeForce GTX').astype(int)

# %%
df["GPU_GeForceGTX"].isnull().sum()
# Out:
# 0

# %%
df.drop(columns=["Gpu"], inplace=True)

# %%
df.drop(columns=["OpSys"], inplace=True)

# %%
# Boxplot de todas las features
numeric_columns = df.select_dtypes(include=['number']).columns

# Configurar el tamaño de la figura
plt.figure(figsize=(15, 5 * len(numeric_columns)))

# Crear un boxplot para cada columna numérica
for i, col in enumerate(numeric_columns, 1):
    plt.subplot(len(numeric_columns), 1, i)
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot de {col}")

plt.tight_layout()
plt.show()

# %%
matriz_corr = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(matriz_corr, cmap="coolwarm", center=0, vmin=-1, vmax=1, annot=True, annot_kws={"size": 8}, fmt=".2f")
plt.show()

# %%
tml.describe_df(df)
# Out:
#                       DATA_TYPE MISSINGS (%) UNIQUE_VALUES CARDIN (%)
# Price_in_euros          float64            0           602      66.08
# apple                     int32            0             2       0.22
# i3                        int32            0             2       0.22
# i5                        int32            0             2       0.22
# i7                        int32            0             2       0.22
# inches                  float64            0            17       1.87
# ram_gb                    int32            0             9       0.99
# weight_kg               float64            0           157      17.23
# Touchscreen               int32            0             2       0.22
# IPS                       int32            0             2       0.22
# 4K                        int32            0             2       0.22
# total_memory_gb         float64            0            23       2.52
# type_Gaming                bool            0             2       0.22
# type_Netbook               bool            0             2       0.22
# type_Notebook              bool            0             2       0.22
# type_Ultrabook             bool            0             2       0.22
# type_Workstation           bool            0             2       0.22
# type_2in1_convertible      bool            0             2       0.22
# total_pixels              int32            0            14       1.54
# GPU_Nvidia                int32            0             2       0.22
# GPU_Intel                 int32            0             2       0.22
# GPU_AMD                   int32            0             2       0.22
# Frecuencia_GHz          float64            0            25       2.74
# GPU_GeForceGTX            int32            0             2       0.22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 911 entries, 755 to 229
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Price_in_euros         911 non-null    float64
#  1   apple                  911 non-null    int32
#  2   i3                     911 non-null    int32
#  3   i5                     911 non-null    int32
#  4   i7                     911 non-null    int32
#  5   inches                 911 non-null    float64
#  6   ram_gb                 911 non-null    int32
#  7   weight_kg              911 non-null    float64
#  8   Touchscreen            911 non-null    int32
#  9   IPS                    911 non-null    int32
#  10  4K                     911 non-null    int32
#  11  total_memory_gb        911 non-null    float64
#  12  type_Gaming            911 non-null    bool
#  13  type_Netbook           911 non-null    bool
#  14  type_Notebook          911 non-null    bool
#  15  type_Ultrabook         911 non-null    bool
#  16  type_Workstation       911 non-null    bool
#  17  type_2in1_convertible  911 non-null    bool
#  18  total_pixels           911 non-null    int32
#  19  GPU_Nvidia             911 non-null    int32
#  20  GPU_Intel              911 non-null    int32
#  21  GPU_AMD                911 non-null    int32
#  22  Frecuencia_GHz         911 non-null    float64
#  23  GPU_GeForceGTX         911 non-null    int32
# dtypes: bool(6), float64(5), int32(13)
# memory usage: 94.3 KB

# %%
# Vamos a sacar las features importantes

X = df.drop(columns="Price_in_euros")
y = df["Price_in_euros"]

modelaje = RandomForestRegressor(random_state=42)
modelaje.fit(X, y)

importantes_features = modelaje.feature_importances_
feature_names = X.columns

feat_importancia = sorted(zip(feature_names, importantes_features), key=lambda x: x[1], reverse=True)
for feature, importance in feat_importancia:
    print(f"{feature}: {importance:.4f}")
# Out:
# ram_gb: 0.4549
# weight_kg: 0.1345
# i7: 0.1124
# type_Notebook: 0.0620
# Frecuencia_GHz: 0.0482
# inches: 0.0365
# i5: 0.0305
# total_pixels: 0.0290
# total_memory_gb: 0.0289
# type_Workstation: 0.0201
# IPS: 0.0100
# GPU_GeForceGTX: 0.0054
# type_Gaming: 0.0042
# type_Ultrabook: 0.0038
# Touchscreen: 0.0037
# GPU_Nvidia: 0.0036
# type_2in1_convertible: 0.0029
# i3: 0.0024
# GPU_Intel: 0.0023
# GPU_AMD: 0.0021
# 4K: 0.0021
# apple: 0.0003
# type_Netbook: 0.0003

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor

selector = SelectFromModel(RandomForestRegressor(n_estimators=100, random_state=42), threshold="median")
selector.fit(X, y)

selected_features = X.columns[selector.get_support()]
print("Features seleccionadas:", selected_features)
# Out:
# Features seleccionadas: Index(['i5', 'i7', 'inches', 'ram_gb', 'weight_kg', 'IPS', 'total_memory_gb',
#        'type_Notebook', 'type_Workstation', 'total_pixels', 'Frecuencia_GHz',
#        'GPU_GeForceGTX'],
#       dtype='object')

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Modelado

# %% [markdown]
# ### 1. Definir X e y

# %%
X = df.drop(['Price_in_euros'], axis=1)
y = df['Price_in_euros'].copy()
X.shape
# Out:
# (910, 23)

# %%
X.columns
# Out:
# Index(['apple', 'i3', 'i5', 'i7', 'inches', 'ram_gb', 'weight_kg',
#        'Touchscreen', 'IPS', '4K', 'total_memory_gb', 'type_Gaming',
#        'type_Netbook', 'type_Notebook', 'type_Ultrabook', 'type_Workstation',
#        'type_2in1_convertible', 'total_pixels', 'GPU_Nvidia', 'GPU_Intel',
#        'GPU_AMD', 'Frecuencia_GHz', 'GPU_GeForceGTX'],
#       dtype='object')

# %%
#X = df.iloc[:, [7,9,10,12,14,20]].copy()
#y = df.iloc[:, 4].copy()

# %%
X = df[["ram_gb", "total_memory_gb","total_pixels","type_Workstation", "Frecuencia_GHz"]].copy()
y = df["Price_in_euros"].copy()

# %%
#X = df[["ram_gb","weight_kg","type_Notebook", "Frecuencia_GHz","i7", "inches", "total_memory_gb", "total_pixels"]].copy()
#y = df["Price_in_euros"].copy()

# %%
X.shape
# Out:
# (910, 5)

# %%
y.shape
# Out:
# (910,)

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %%
y_bins = pd.qcut(y, q=10, duplicates='drop')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify=y_bins, random_state=42)

# %%
X_train = X_train.astype({"type_Notebook": int, "type_Workstation": int})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20980\1515156628.py in ?()
# ----> 1 X_train = X_train.astype({"type_Notebook": int, "type_Workstation": int})
#
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy, errors)
#    6601             dtype_ser = Series(dtype, dtype=object)
#    6602
#    6603             for col_name in dtype_ser.index:
#    6604                 if col_name not in self:
# -> 6605                     raise KeyError(
#    6606                         "Only a column name can be used for the "
#    6607                         "key in a dtype mappings argument. "
#    6608                         f"'{col_name}' not found in columns."
#
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'type_Notebook' not found in columns."

# %%
X_train
# Out:
#       ram_gb  total_memory_gb  total_pixels  type_Workstation  Frecuencia_GHz
# 76         8           1024.0       1049088             False             2.0
# 501       24           1280.0       2073600             False             2.6
# 466        8            256.0       1440000             False             2.0
# 835        8            256.0       2073600             False             2.5
# 706       16            512.0       2073600             False             2.5
# ...      ...              ...           ...               ...             ...
# 1074       8            256.0       2073600             False             2.7
# 1080       8            256.0       2073600             False             2.7
# 354        4             32.0       1049088             False             1.1
# 146        4            500.0       1049088             False             2.3
# 1303      16            512.0       5760000             False             2.5
#
# [728 rows x 5 columns]

# %%
y_train
# Out:
# 76       389.0
# 501     1269.0
# 466      639.9
# 835     1358.0
# 706     1877.0
#          ...
# 1074    1070.0
# 1080    1458.0
# 354      375.0
# 146      602.0
# 1303    1499.0
# Name: Price_in_euros, Length: 728, dtype: float64

# %% [markdown]
# ### 3. Baseline de modelos

# %%
xgb_model = XGBRegressor(n_estimators=200, max_depth = 6, leaning_rate=0.1, random_state=42)
xgb_model.fit(X_train, y_train)

y_pred_xgb = xgb_model.predict(X_test)
rmse_xgb = root_mean_squared_error(y_test,y_pred_xgb)
print(F"RMSE con XGBoost (sin escalar): {rmse_xgb:.4f}")
# Out:
# RMSE con XGBoost (sin escalar): 382.7395
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\xgboost\core.py:158: UserWarning: [13:47:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "leaning_rate" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
RFmodel = RandomForestRegressor()
RFmodel.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
X_test = X_test.astype({"type_Notebook": int, "type_Workstation": int})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20980\1243204369.py in ?()
# ----> 1 X_test = X_test.astype({"type_Notebook": int, "type_Workstation": int})
#
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy, errors)
#    6601             dtype_ser = Series(dtype, dtype=object)
#    6602
#    6603             for col_name in dtype_ser.index:
#    6604                 if col_name not in self:
# -> 6605                     raise KeyError(
#    6606                         "Only a column name can be used for the "
#    6607                         "key in a dtype mappings argument. "
#    6608                         f"'{col_name}' not found in columns."
#
# KeyError: "Only a column name can be used for the key in a dtype mappings argument. 'type_Notebook' not found in columns."

# %%
y_pred = RFmodel.predict(X_test)

# %% [markdown]
# ### 4. Sacar métricas, valorar los modelos
#
# Recuerda que en la competición se va a evaluar con la métrica de ``RMSE``.

# %%
RMSE = root_mean_squared_error(y_test, y_pred)
RMSE
# Out:
# 353.4675480738503

# %%
# Para buscar mejores parametros
param_dist = {
    'n_estimators': np.arange(50, 300, 50),
    'max_depth': [None, 10, 20, 30, 50],
    'min_samples_split': np.arange(2, 15, 2),
    'min_samples_leaf': np.arange(1, 10, 2),
    'max_features': ['auto', 'sqrt']
}

random_search = RandomizedSearchCV(
    estimator=RFmodel,
    param_distributions=param_dist,
    n_iter=20,
    scoring='neg_root_mean_squared_error',
    cv=5,
    n_jobs=-1,
    verbose=2,
    random_state=42
)

random_search.fit(X_train,y_train)

print(f"Mejores parámetros: {random_search.best_params_}")
print(f"Mejor RMSE: {random_search.best_score_}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Usuario\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1107: UserWarning: One or more of the test scores are non-finite: [-339.780315             nan -378.48024203           nan           nan
#  -340.67851231 -340.75868653           nan -340.45621758           nan
#            nan           nan           nan -345.69284079 -388.17313678
#  -339.21980629           nan           nan           nan           nan]
#   warnings.warn(
# Mejores parámetros: {'n_estimators': 200, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None}
# Mejor RMSE: -339.21980629366425

# %%
best_params = random_search.best_params_
print(best_params)
# Out:
# {'n_estimators': 200, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': None}

# %%
# Con hiperparámetros optimizados
final_model = RandomForestRegressor(**best_params, random_state=42)

final_model.fit(X_train, y_train)

y_pred_optimizado = final_model.predict(X_test)

# %%
rmse_baseline = root_mean_squared_error(y_test, y_pred)
rmse_optimized = root_mean_squared_error(y_test, y_pred_optimizado)

print(f"RMSE Baseline: {rmse_baseline:.2f}")
print(f"RMSE Optimizado: {rmse_optimized:.2f}")
# Out:
# RMSE Baseline: 353.47
# RMSE Optimizado: 340.17

# %%
# Comparar el RMSE en entrenamiento y validación
y_train_pred = final_model.predict(X_train)

rmse_train = root_mean_squared_error(y_train, y_train_pred)
rmse_test = root_mean_squared_error(y_test, y_pred_optimizado)

print(f"RMSE en Entrenamiento: {rmse_train:.4f}")
print(f"RMSE en Test: {rmse_test:.4f}")
# Out:
# RMSE en Entrenamiento: 267.2317
# RMSE en Test: 340.1653

# %%
# Vamos a tocar los best_params para ver si podemos mejorar el modelo
#best_params["max_depth"] = None
#best_params["min_samples_leaf"] = 1
#best_params["min_samples_split"] = 6

# %%
plt.figure(figsize=(8,4))
plt.hist(y_train, bins=30, alpha=0.7, label="Train")
plt.hist(y_test, bins=30, alpha=0.7, label="Test")
plt.legend()
plt.xlabel("Price")
plt.ylabel("Frecuencia")
plt.title("Distribución de Precios en Train y Test")
plt.show()

# %%
#df.Price_in_euros.value_counts().sort_index(ascending=False)

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir ``test.csv``

# %% [markdown]
# **RECUERDA: APLICAR LAS TRANSFORMACIONES QUE HAYAS REALIZADO EN `train.csv` a `test.csv`.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ### 1. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("./data/test.csv", index_col=0)
X_pred.index.name = None
X_pred
# Out:
#       Company                          Product            TypeName  Inches  \
# 209    Lenovo               Legion Y520-15IKBN              Gaming    15.6
# 1281     Acer                   Aspire ES1-531            Notebook    15.6
# 1168   Lenovo  V110-15ISK (i3-6006U/4GB/1TB/No            Notebook    15.6
# 1231     Dell                    Inspiron 7579  2 in 1 Convertible    15.6
# 1020       HP                      ProBook 640            Notebook    14.0
# ...       ...                              ...                 ...     ...
# 820       MSI                      GE72MVR 7RG              Gaming    17.3
# 948   Toshiba                  Tecra Z40-C-12X            Notebook    14.0
# 483      Dell                  Precision M5520         Workstation    15.6
# 1017       HP                      Probook 440            Notebook    14.0
# 421      Asus                     ZenBook Flip  2 in 1 Convertible    13.3
#
#                                ScreenResolution  \
# 209                           Full HD 1920x1080
# 1281                                   1366x768
# 1168                                   1366x768
# 1231  IPS Panel Full HD / Touchscreen 1920x1080
# 1020                          Full HD 1920x1080
# ...                                         ...
# 820                           Full HD 1920x1080
# 948                 IPS Panel Full HD 1920x1080
# 483                           Full HD 1920x1080
# 1017                                   1366x768
# 421   IPS Panel Full HD / Touchscreen 1920x1080
#
#                                        Cpu   Ram                Memory  \
# 209            Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 1281  Intel Celeron Dual Core N3060 1.6GHz   4GB             500GB HDD
# 1168            Intel Core i3 6006U 2.0GHz   4GB               1TB HDD
# 1231            Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 1020            Intel Core i5 7200U 2.5GHz   4GB             256GB SSD
# ...                                    ...   ...                   ...
# 820            Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD +  1TB HDD
# 948             Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 483            Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1017            Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 421             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
#
#                           Gpu       OpSys   Weight
# 209   Nvidia GeForce GTX 1060       No OS    2.4kg
# 1281    Intel HD Graphics 400       Linux    2.4kg
# 1168    Intel HD Graphics 520       No OS    1.9kg
# 1231    Intel HD Graphics 620  Windows 10  2.191kg
# 1020    Intel HD Graphics 620  Windows 10   1.95kg
# ...                       ...         ...      ...
# 820   Nvidia GeForce GTX 1070  Windows 10    2.9kg
# 948     Intel HD Graphics 520  Windows 10   1.47kg
# 483       Nvidia Quadro M1200  Windows 10   1.78kg
# 1017    Intel HD Graphics 620  Windows 10   1.64kg
# 421     Intel HD Graphics 620  Windows 10   1.27kg
#
# [391 rows x 11 columns]

# %%
X_pred['apple'] = X_pred['Company'].str.contains(r'Apple', case=False, na=False).astype(int)

# %%
X_pred.drop(columns=["Company", "Product"], inplace=True)

# %%
X_pred['i3'] = X_pred['Cpu'].str.contains(r'i3', case=False, na=False).astype(int)
X_pred['i5'] = X_pred['Cpu'].str.contains(r'i5', case=False, na=False).astype(int)
X_pred['i7'] = X_pred['Cpu'].str.contains(r'i7', case=False, na=False).astype(int)

# %%
X_pred["inches"] = X_pred.Inches.astype(float)
X_pred['ram_gb'] = X_pred['Ram'].str.replace('GB', '').astype(int)
X_pred["weight_kg"] = X_pred['Weight'].str.replace('kg', '').astype(float)

# %%
X_pred["Touchscreen"] = X_pred["ScreenResolution"].str.contains("Touchscreen").astype(int)

# %%
X_pred["IPS"] = X_pred["ScreenResolution"].str.contains("IPS").astype(int)

# %%
X_pred["4K"] = X_pred["ScreenResolution"].str.contains("4K").astype(int)

# %%
find_GB_TB = X_pred["Memory"].str.findall(r"(\d+)(GB|TB)")

def convert_to_gb(list_of_tuples):
    total_gb = 0
    if list_of_tuples: 
        for (num, unit) in list_of_tuples:
            num = float(num)
            if unit == "TB":
                total_gb += num * 1024
            else: 
                total_gb += num
    return total_gb

X_pred["total_memory_gb"] = find_GB_TB.apply(convert_to_gb)

# %%
X_pred = pd.get_dummies(X_pred, columns=["TypeName"], prefix="type")
X_pred["type_2in1_convertible"] = X_pred["type_2 in 1 Convertible"]
X_pred.drop("type_2 in 1 Convertible", axis=1, inplace=True)
X_pred
# Out:
#       Inches                           ScreenResolution  \
# 209     15.6                          Full HD 1920x1080
# 1281    15.6                                   1366x768
# 1168    15.6                                   1366x768
# 1231    15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 1020    14.0                          Full HD 1920x1080
# ...      ...                                        ...
# 820     17.3                          Full HD 1920x1080
# 948     14.0                IPS Panel Full HD 1920x1080
# 483     15.6                          Full HD 1920x1080
# 1017    14.0                                   1366x768
# 421     13.3  IPS Panel Full HD / Touchscreen 1920x1080
#
#                                        Cpu   Ram                Memory  \
# 209            Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 1281  Intel Celeron Dual Core N3060 1.6GHz   4GB             500GB HDD
# 1168            Intel Core i3 6006U 2.0GHz   4GB               1TB HDD
# 1231            Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 1020            Intel Core i5 7200U 2.5GHz   4GB             256GB SSD
# ...                                    ...   ...                   ...
# 820            Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD +  1TB HDD
# 948             Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 483            Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1017            Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 421             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
#
#                           Gpu       OpSys   Weight  apple  i3  ...  \
# 209   Nvidia GeForce GTX 1060       No OS    2.4kg      0   0  ...
# 1281    Intel HD Graphics 400       Linux    2.4kg      0   0  ...
# 1168    Intel HD Graphics 520       No OS    1.9kg      0   1  ...
# 1231    Intel HD Graphics 620  Windows 10  2.191kg      0   0  ...
# 1020    Intel HD Graphics 620  Windows 10   1.95kg      0   0  ...
# ...                       ...         ...      ...    ...  ..  ...
# 820   Nvidia GeForce GTX 1070  Windows 10    2.9kg      0   0  ...
# 948     Intel HD Graphics 520  Windows 10   1.47kg      0   0  ...
# 483       Nvidia Quadro M1200  Windows 10   1.78kg      0   0  ...
# 1017    Intel HD Graphics 620  Windows 10   1.64kg      0   0  ...
# 421     Intel HD Graphics 620  Windows 10   1.27kg      0   0  ...
#
#       Touchscreen  IPS  4K  total_memory_gb  type_Gaming  type_Netbook  \
# 209             0    0   0            512.0         True         False
# 1281            0    0   0            500.0        False         False
# 1168            0    0   0           1024.0        False         False
# 1231            1    1   0            256.0        False         False
# 1020            0    0   0            256.0        False         False
# ...           ...  ...  ..              ...          ...           ...
# 820             0    0   0           1536.0         True         False
# 948             0    1   0            128.0        False         False
# 483             0    0   0            256.0        False         False
# 1017            0    0   0            500.0        False         False
# 421             1    1   0            256.0        False         False
#
#       type_Notebook  type_Ultrabook  type_Workstation  type_2in1_convertible
# 209           False           False             False                  False
# 1281           True           False             False                  False
# 1168           True           False             False                  False
# 1231          False           False             False                   True
# 1020           True           False             False                  False
# ...             ...             ...               ...                    ...
# 820           False           False             False                  False
# 948            True           False             False                  False
# 483           False           False              True                  False
# 1017           True           False             False                  False
# 421           False           False             False                   True
#
# [391 rows x 25 columns]

# %%
X_pred[["width", "height"]] = X_pred["ScreenResolution"].str.extract(r"(\d+)x(\d+)").astype(int)
X_pred["total_pixels"] = X_pred["width"] * X_pred["height"]
X_pred.head
# Out:
# <bound method NDFrame.head of       Inches                           ScreenResolution  \
# 209     15.6                          Full HD 1920x1080
# 1281    15.6                                   1366x768
# 1168    15.6                                   1366x768
# 1231    15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 1020    14.0                          Full HD 1920x1080
# ...      ...                                        ...
# 820     17.3                          Full HD 1920x1080
# 948     14.0                IPS Panel Full HD 1920x1080
# 483     15.6                          Full HD 1920x1080
# 1017    14.0                                   1366x768
# 421     13.3  IPS Panel Full HD / Touchscreen 1920x1080
#
#                                        Cpu   Ram                Memory  \
# 209            Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 1281  Intel Celeron Dual Core N3060 1.6GHz   4GB             500GB HDD
# 1168            Intel Core i3 6006U 2.0GHz   4GB               1TB HDD
# 1231            Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 1020            Intel Core i5 7200U 2.5GHz   4GB             256GB SSD
# ...                                    ...   ...                   ...
# 820            Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD +  1TB HDD
# 948             Intel Core i5 6200U 2.3GHz   4GB             128GB SSD
# 483            Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1017            Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 421             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
#
#                           Gpu       OpSys   Weight  apple  i3  ...  \
# 209   Nvidia GeForce GTX 1060       No OS    2.4kg      0   0  ...
# 1281    Intel HD Graphics 400       Linux    2.4kg      0   0  ...
# 1168    Intel HD Graphics 520       No OS    1.9kg      0   1  ...
# 1231    Intel HD Graphics 620  Windows 10  2.191kg      0   0  ...
# 1020    Intel HD Graphics 620  Windows 10   1.95kg      0   0  ...
# ...                       ...         ...      ...    ...  ..  ...
# 820   Nvidia GeForce GTX 1070  Windows 10    2.9kg      0   0  ...
# 948     Intel HD Graphics 520  Windows 10   1.47kg      0   0  ...
# 483       Nvidia Quadro M1200  Windows 10   1.78kg      0   0  ...
# 1017    Intel HD Graphics 620  Windows 10   1.64kg      0   0  ...
# 421     Intel HD Graphics 620  Windows 10   1.27kg      0   0  ...
#
#       total_memory_gb  type_Gaming  type_Netbook  type_Notebook  \
# 209             512.0         True         False          False
# 1281            500.0        False         False           True
# 1168           1024.0        False         False           True
# 1231            256.0        False         False          False
# 1020            256.0        False         False           True
# ...               ...          ...           ...            ...
# 820            1536.0         True         False          False
# 948             128.0        False         False           True
# 483             256.0        False         False          False
# 1017            500.0        False         False           True
# 421             256.0        False         False          False
#
#       type_Ultrabook  type_Workstation  type_2in1_convertible  width  height  \
# 209            False             False                  False   1920    1080
# 1281           False             False                  False   1366     768
# 1168           False             False                  False   1366     768
# 1231           False             False                   True   1920    1080
# 1020           False             False                  False   1920    1080
# ...              ...               ...                    ...    ...     ...
# 820            False             False                  False   1920    1080
# 948            False             False                  False   1920    1080
# 483            False              True                  False   1920    1080
# 1017           False             False                  False   1366     768
# 421            False             False                   True   1920    1080
#
#       total_pixels
# 209        2073600
# 1281       1049088
# 1168       1049088
# 1231       2073600
# 1020       2073600
# ...            ...
# 820        2073600
# 948        2073600
# 483        2073600
# 1017       1049088
# 421        2073600
#
# [391 rows x 28 columns]>

# %%
X_pred['GPU_Nvidia'] = X_pred['Gpu'].str.contains('Nvidia').astype(int)
X_pred['GPU_Intel'] = X_pred['Gpu'].str.contains('Intel').astype(int)
X_pred['GPU_AMD'] = X_pred['Gpu'].str.contains('AMD').astype(int)

print(X_pred['GPU_AMD'].sum()+X_pred['GPU_Intel'].sum()+X_pred['GPU_Nvidia'].sum())
# Out:
# 390

# %%
X_pred["Frecuencia_GHz"] = X_pred["Cpu"].str.extract(r"(\d+(?:\.\d+)?)GHz")
X_pred.Frecuencia_GHz = X_pred["Frecuencia_GHz"].astype(float)

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Inches                 391 non-null    float64
#  1   ScreenResolution       391 non-null    object
#  2   Cpu                    391 non-null    object
#  3   Ram                    391 non-null    object
#  4   Memory                 391 non-null    object
#  5   Gpu                    391 non-null    object
#  6   OpSys                  391 non-null    object
#  7   Weight                 391 non-null    object
#  8   apple                  391 non-null    int32
#  9   i3                     391 non-null    int32
#  10  i5                     391 non-null    int32
#  11  i7                     391 non-null    int32
#  12  inches                 391 non-null    float64
#  13  ram_gb                 391 non-null    int32
#  14  weight_kg              391 non-null    float64
#  15  Touchscreen            391 non-null    int32
#  16  IPS                    391 non-null    int32
#  17  4K                     391 non-null    int32
#  18  total_memory_gb        391 non-null    float64
#  19  type_Gaming            391 non-null    bool
#  20  type_Netbook           391 non-null    bool
#  21  type_Notebook          391 non-null    bool
#  22  type_Ultrabook         391 non-null    bool
#  23  type_Workstation       391 non-null    bool
#  24  type_2in1_convertible  391 non-null    bool
#  25  width                  391 non-null    int32
#  26  height                 391 non-null    int32
#  27  total_pixels           391 non-null    int32
#  28  GPU_Nvidia             391 non-null    int32
#  29  GPU_Intel              391 non-null    int32
#  30  GPU_AMD                391 non-null    int32
#  31  Frecuencia_GHz         391 non-null    float64
# dtypes: bool(6), float64(5), int32(14), object(7)
# memory usage: 63.4+ KB

# %%
X_pred.drop(columns=["Cpu","Memory", "Ram", "Inches", "Weight", "ScreenResolution"], inplace=True)
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gpu                    391 non-null    object
#  1   OpSys                  391 non-null    object
#  2   apple                  391 non-null    int32
#  3   i3                     391 non-null    int32
#  4   i5                     391 non-null    int32
#  5   i7                     391 non-null    int32
#  6   inches                 391 non-null    float64
#  7   ram_gb                 391 non-null    int32
#  8   weight_kg              391 non-null    float64
#  9   Touchscreen            391 non-null    int32
#  10  IPS                    391 non-null    int32
#  11  4K                     391 non-null    int32
#  12  total_memory_gb        391 non-null    float64
#  13  type_Gaming            391 non-null    bool
#  14  type_Netbook           391 non-null    bool
#  15  type_Notebook          391 non-null    bool
#  16  type_Ultrabook         391 non-null    bool
#  17  type_Workstation       391 non-null    bool
#  18  type_2in1_convertible  391 non-null    bool
#  19  width                  391 non-null    int32
#  20  height                 391 non-null    int32
#  21  total_pixels           391 non-null    int32
#  22  GPU_Nvidia             391 non-null    int32
#  23  GPU_Intel              391 non-null    int32
#  24  GPU_AMD                391 non-null    int32
#  25  Frecuencia_GHz         391 non-null    float64
# dtypes: bool(6), float64(4), int32(14), object(2)
# memory usage: 45.1+ KB

# %%
X_pred.tail()
# Out:
#                           Gpu       OpSys  apple  i3  i5  i7  inches  ram_gb  \
# 820   Nvidia GeForce GTX 1070  Windows 10      0   0   0   1    17.3      16
# 948     Intel HD Graphics 520  Windows 10      0   0   1   0    14.0       4
# 483       Nvidia Quadro M1200  Windows 10      0   0   0   1    15.6       8
# 1017    Intel HD Graphics 620  Windows 10      0   0   1   0    14.0       4
# 421     Intel HD Graphics 620  Windows 10      0   0   1   0    13.3       8
#
#       weight_kg  Touchscreen  ...  type_Ultrabook  type_Workstation  \
# 820        2.90            0  ...           False             False
# 948        1.47            0  ...           False             False
# 483        1.78            0  ...           False              True
# 1017       1.64            0  ...           False             False
# 421        1.27            1  ...           False             False
#
#       type_2in1_convertible  width  height  total_pixels  GPU_Nvidia  \
# 820                   False   1920    1080       2073600           1
# 948                   False   1920    1080       2073600           0
# 483                   False   1920    1080       2073600           1
# 1017                  False   1366     768       1049088           0
# 421                    True   1920    1080       2073600           0
#
#       GPU_Intel  GPU_AMD  Frecuencia_GHz
# 820           0        0             2.8
# 948           1        0             2.3
# 483           0        0             2.8
# 1017          1        0             2.5
# 421           1        0             2.5
#
# [5 rows x 26 columns]

# %%
X_pred.drop(columns=["width", "height"], inplace=True)

# %%
X_pred['GPU_GeForceGTX'] = X_pred['Gpu'].str.contains('GeForce GTX').astype(int)

# %%
X_pred.drop(columns=["Gpu"], inplace=True)

# %%
X_pred.drop(columns=["OpSys"], inplace=True)

# %%
X_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 391 entries, 209 to 421
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   apple                  391 non-null    int32
#  1   i3                     391 non-null    int32
#  2   i5                     391 non-null    int32
#  3   i7                     391 non-null    int32
#  4   inches                 391 non-null    float64
#  5   ram_gb                 391 non-null    int32
#  6   weight_kg              391 non-null    float64
#  7   Touchscreen            391 non-null    int32
#  8   IPS                    391 non-null    int32
#  9   4K                     391 non-null    int32
#  10  total_memory_gb        391 non-null    float64
#  11  type_Gaming            391 non-null    bool
#  12  type_Netbook           391 non-null    bool
#  13  type_Notebook          391 non-null    bool
#  14  type_Ultrabook         391 non-null    bool
#  15  type_Workstation       391 non-null    bool
#  16  type_2in1_convertible  391 non-null    bool
#  17  total_pixels           391 non-null    int32
#  18  GPU_Nvidia             391 non-null    int32
#  19  GPU_Intel              391 non-null    int32
#  20  GPU_AMD                391 non-null    int32
#  21  Frecuencia_GHz         391 non-null    float64
#  22  GPU_GeForceGTX         391 non-null    int32
# dtypes: bool(6), float64(4), int32(13)
# memory usage: 37.4 KB

# %%
#X_pred = X_pred.iloc[:, [6,8,9,11,13,19]].copy()

# %%
X_pred = X_pred.astype({"type_Notebook": int})

# %%
X_pred = X_pred[["ram_gb", "total_memory_gb","total_pixels","type_Workstation", "Frecuencia_GHz"]].copy()

# %% [markdown]
#  ## 2. Replicar el procesado para ``test.csv``

# %%
X_pred
# Out:
#       ram_gb  total_memory_gb  total_pixels  type_Workstation  Frecuencia_GHz
# 209       16            512.0       2073600             False             2.8
# 1281       4            500.0       1049088             False             1.6
# 1168       4           1024.0       1049088             False             2.0
# 1231       8            256.0       2073600             False             2.5
# 1020       4            256.0       2073600             False             2.5
# ...      ...              ...           ...               ...             ...
# 820       16           1536.0       2073600             False             2.8
# 948        4            128.0       2073600             False             2.3
# 483        8            256.0       2073600              True             2.8
# 1017       4            500.0       1049088             False             2.5
# 421        8            256.0       2073600             False             2.5
#
# [391 rows x 5 columns]

# %%
predictions_submit = RFmodel.predict(X_pred)
predictions_submit
# Out:
# array([1817.52370595,  383.48062662,  473.45993437, 1160.17038834,
#         843.19241524,  491.36007024, 1288.6174256 , 1086.14067389,
#        1749.31396306,  334.3290754 , 1865.23635438, 1086.14067389,
#         556.65585465, 1765.22099877,  743.90101456,  549.0100873 ,
#        1715.01867619, 1086.14067389, 1508.28568864,  843.19241524,
#        1663.51431365,  261.32267911,  556.7226131 , 1637.27699552,
#         500.45748881,  750.901     ,  543.0794    ,  404.27374242,
#        2390.22568788, 1160.17038834, 1865.23635438,  473.45993437,
#         646.74678134, 2837.6375    , 1957.66551068, 1865.23635438,
#         596.03636405, 1347.81122587, 1037.963     , 1160.17038834,
#         474.01673333,  832.012     ,  550.28756667, 1324.47011873,
#        1288.78266121, 1151.35877044, 1160.17038834,  772.23965645,
#        1160.17038834,  487.53703472, 1817.52370595,  976.50307143,
#        1282.7126134 ,  807.60483873, 1978.12663333, 1700.73987024,
#         744.25038672,  976.50307143,  750.901     ,  693.17131905,
#        2572.95631619, 1982.2132    ,  601.29618611, 2119.9947    ,
#        1352.17695138, 1352.17695138,  843.19241524, 1749.31396306,
#        1517.7       , 2415.56982456,  747.96733406,  334.3290754 ,
#        1160.17038834, 1670.18637619, 1160.17038834, 1185.84515178,
#        1813.74899229, 1670.18637619, 1865.23635438, 1160.17038834,
#         750.901     , 1835.28993915, 2329.8182    , 1508.28568864,
#        1643.68878607, 2142.92167571,  419.70882143, 1151.35877044,
#         806.12664444,  747.96733406,  628.65844048, 2037.90595067,
#        1160.17038834, 2854.5775    , 2393.271755  , 1408.9415784 ,
